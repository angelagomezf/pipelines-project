# %% [markdown]
# # Data Cleaning

# %% [markdown]
# - First things first: choosing a dataset and cleaning it, to then proceed to enriching and analyzing it.
# - For this project I have chosen "the most followed accounts on Instagram" database from Kaggle.

# %% [markdown]
# ## 1. Loading the data

# %% [markdown]
# #### Let's import the libraries first

# %%
import pandas as pd 
import numpy as np
import re
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# #### And now, let's load the data

# %%
df = pd.read_csv('most_followed_ig.csv', encoding = 'Windows-1252')
df
# Out:
#     RANK                   BRAND CATEGORIES 1 CATEGORIES 2   FOLLOWERS  \
# 0      1            Selena Gomez  celebrities    musicians  105.4Mæ(=)
# 1      2            Taylor Swift  celebrities    musicians   95.2Mæ(=)
# 2      3           Ariana Grande  celebrities    musicians   92.3Mæ(=)
# 3      4                 Beyonce  celebrities    musicians   90.6Mæ(=)
# 4      5     Kim Kardashian West  celebrities           tv   89.3Mæ(=)
# ..   ...                     ...          ...          ...         ...
# 95    96  DanialvesD2 My Twitter  celebrities     athletes   11.7Mæ(=)
# 96    97         Dolce & Gabbana      fashion       luxury   11.7Mæ(=)
# 97    98           Tyga / T-Raww  celebrities    musicians   11.6Mæ(=)
# 98    99       Paul Labile Pogba  celebrities     athletes   11.5Mæ(=)
# 99   100            Barack Obama  celebrities    political   11.5Mæ(=)
#
#               ER iPOSTS ON HASHTAG MEDIA POSTED
# 0   2.62%æ(1342)        14.5Mæ(48)  1.2kæ(2135)
# 1   1.96%æ(2040)        10.5Mæ(66)   958æ(2669)
# 2   1.43%æ(2759)        16.9Mæ(41)   2.8kæ(824)
# 3   2.53%æ(1427)         9.2Mæ(70)  1.4kæ(1897)
# 4   1.39%æ(2812)        5.1Mæ(130)   3.6kæ(550)
# ..           ...               ...          ...
# 95  1.62%æ(2477)     122.4kæ(1486)  1.7kæ(1508)
# 96  0.48%æ(4142)        6.1Mæ(105)   3.9kæ(471)
# 97  1.31%æ(2922)        1.2Mæ(421)   2.5kæ(948)
# 98   6.11%æ(170)      77.6kæ(1745)   396æ(4219)
# 99   3.37%æ(826)        2.5Mæ(240)   231æ(4753)
#
# [100 rows x 8 columns]

# %% [markdown]
# ## 2. Exploratory Analysis

# %%
df.shape
# Out:
# (100, 8)

# %%
df.dtypes
# Out:
# RANK                  int64
# BRAND                object
# CATEGORIES 1         object
# CATEGORIES 2         object
# FOLLOWERS            object
# ER                   object
# iPOSTS ON HASHTAG    object
# MEDIA POSTED         object
# dtype: object

# %%
df.columns.values
# Out:
# array(['RANK', 'BRAND', 'CATEGORIES 1', 'CATEGORIES 2', 'FOLLOWERS', 'ER',
#        'iPOSTS ON HASHTAG', 'MEDIA POSTED'], dtype=object)

# %% [markdown]
# ### Renaming columns

# %%
df.rename(columns = {'CATEGORIES 1':'CATEGORIES', 'CATEGORIES 2':'SUBCATEGORIES'}, inplace = True)

# %%
df
# Out:
#     RANK                   BRAND   CATEGORIES SUBCATEGORIES   FOLLOWERS  \
# 0      1            Selena Gomez  celebrities     musicians  105.4Mæ(=)
# 1      2            Taylor Swift  celebrities     musicians   95.2Mæ(=)
# 2      3           Ariana Grande  celebrities     musicians   92.3Mæ(=)
# 3      4                 Beyonce  celebrities     musicians   90.6Mæ(=)
# 4      5     Kim Kardashian West  celebrities            tv   89.3Mæ(=)
# ..   ...                     ...          ...           ...         ...
# 95    96  DanialvesD2 My Twitter  celebrities      athletes   11.7Mæ(=)
# 96    97         Dolce & Gabbana      fashion        luxury   11.7Mæ(=)
# 97    98           Tyga / T-Raww  celebrities     musicians   11.6Mæ(=)
# 98    99       Paul Labile Pogba  celebrities      athletes   11.5Mæ(=)
# 99   100            Barack Obama  celebrities     political   11.5Mæ(=)
#
#               ER iPOSTS ON HASHTAG MEDIA POSTED
# 0   2.62%æ(1342)        14.5Mæ(48)  1.2kæ(2135)
# 1   1.96%æ(2040)        10.5Mæ(66)   958æ(2669)
# 2   1.43%æ(2759)        16.9Mæ(41)   2.8kæ(824)
# 3   2.53%æ(1427)         9.2Mæ(70)  1.4kæ(1897)
# 4   1.39%æ(2812)        5.1Mæ(130)   3.6kæ(550)
# ..           ...               ...          ...
# 95  1.62%æ(2477)     122.4kæ(1486)  1.7kæ(1508)
# 96  0.48%æ(4142)        6.1Mæ(105)   3.9kæ(471)
# 97  1.31%æ(2922)        1.2Mæ(421)   2.5kæ(948)
# 98   6.11%æ(170)      77.6kæ(1745)   396æ(4219)
# 99   3.37%æ(826)        2.5Mæ(240)   231æ(4753)
#
# [100 rows x 8 columns]

# %% [markdown]
# ### Removing special characters

# %%
df.replace('æ','',regex=True, inplace=True)

# %%
df.replace('\(.*\)','',regex=True, inplace=True)

# %%
df
# Out:
#     RANK                   BRAND   CATEGORIES SUBCATEGORIES FOLLOWERS     ER  \
# 0      1            Selena Gomez  celebrities     musicians    105.4M  2.62%
# 1      2            Taylor Swift  celebrities     musicians     95.2M  1.96%
# 2      3           Ariana Grande  celebrities     musicians     92.3M  1.43%
# 3      4                 Beyonce  celebrities     musicians     90.6M  2.53%
# 4      5     Kim Kardashian West  celebrities            tv     89.3M  1.39%
# ..   ...                     ...          ...           ...       ...    ...
# 95    96  DanialvesD2 My Twitter  celebrities      athletes     11.7M  1.62%
# 96    97         Dolce & Gabbana      fashion        luxury     11.7M  0.48%
# 97    98           Tyga / T-Raww  celebrities     musicians     11.6M  1.31%
# 98    99       Paul Labile Pogba  celebrities      athletes     11.5M  6.11%
# 99   100            Barack Obama  celebrities     political     11.5M  3.37%
#
#    iPOSTS ON HASHTAG MEDIA POSTED
# 0              14.5M         1.2k
# 1              10.5M          958
# 2              16.9M         2.8k
# 3               9.2M         1.4k
# 4               5.1M         3.6k
# ..               ...          ...
# 95            122.4k         1.7k
# 96              6.1M         3.9k
# 97              1.2M         2.5k
# 98             77.6k          396
# 99              2.5M          231
#
# [100 rows x 8 columns]

# %% [markdown]
# ### Null values

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# SUBCATEGORIES        9
# MEDIA POSTED         0
# iPOSTS ON HASHTAG    0
# ER                   0
# FOLLOWERS            0
# CATEGORIES           0
# BRAND                0
# RANK                 0
# dtype: int64
